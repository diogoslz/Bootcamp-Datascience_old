# %% [markdown]
# ### AULA 01

# %%
import pandas as pd

# %%
dados = pd.read_csv('A225850189_28_143_208.csv', encoding='ISO-8859-1', sep=';', skiprows=3,
                    skipfooter=12, thousands='.', decimal=',')
# Out:
# <ipython-input-2-e0b23d820060>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv('A225850189_28_143_208.csv', encoding='ISO-8859-1', sep=';', skiprows=3,

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Dez    5.377291e+07
# 2021/Jan    4.947411e+07
# 2021/Fev    3.899242e+07
# 2021/Mar    2.416371e+07
# Total       6.388206e+09
# Length: 165, dtype: float64

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
dados['2008/Jan']
# Out:
# 0        1,829,559.71
# 1        1,731,744.62
# 2       11,419,210.08
# 3          808,448.39
# 4       21,762,104.16
# 5        1,329,876.61
# 6        5,136,474.61
# 7       21,551,600.33
# 8       11,375,419.37
# 9       32,444,328.54
# 10      11,763,899.23
# 11      16,599,004.84
# 12      51,261,210.58
# 13      16,568,724.64
# 14       5,439,985.99
# 15      73,947,845.87
# 16     206,208,080.90
# 17      16,212,109.41
# 18     251,511,992.03
# 19   1,038,067,423.15
# 20      58,081,334.45
# 21      53,034,384.67
# 22      51,064,610.03
# 23       8,301,006.10
# 24       8,213,438.64
# 25      75,039,013.46
# 26      10,561,085.46
# Name: 2008/Jan, dtype: float64

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")
plt.show()

# %% [markdown]
# ### Desafio 01: Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.

# %%
ax = dados.sort_values('2020/Dez', ascending=False).plot(x='Unidade da Federação', y='2020/Dez', kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valores Gasto da Saúde por unidade da federação (R$)")
plt.show()

# %% [markdown]
# ### AULA 02

# %%
dados[["2008/Ago","2008/Set"]].head()
# Out:
#        2008/Ago      2008/Set
# 0  2,938,286.29  2,843,930.91
# 1  1,886,871.84  2,084,884.80
# 2  8,331,763.97  8,148,089.92
# 3  1,045,291.11  1,003,740.89
# 4 23,259,148.28 23,667,690.01

# %%
dados.mean()
# Out:
# 2007/Ago         304,952.77
# 2007/Set         788,145.26
# 2007/Out       2,440,162.96
# 2007/Nov       5,517,354.05
# 2007/Dez      12,337,159.42
#                  ...
# 2020/Dez      53,772,909.13
# 2021/Jan      49,474,107.60
# 2021/Fev      38,992,424.23
# 2021/Mar      24,163,712.88
# Total      6,388,205,992.19
# Length: 165, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0,"Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação   2007/Ago   2007/Set     2007/Out     2007/Nov  \
# 0          11 Rondônia   4,209.37  16,397.03   133,645.19   346,912.84
# 1              12 Acre  10,470.07  14,001.71    86,200.85   301,323.68
# 2          13 Amazonas  35,752.72  45,570.64   416,012.30 2,020,381.79
# 3           14 Roraima   4,785.91  11,858.63    43,852.67   369,328.51
# 4              15 Pará 181,159.29 433,414.74 1,893,197.50 5,105,406.44
#
#        2007/Dez      2008/Jan      2008/Fev      2008/Mar      2008/Abr  ...  \
# 0    711,758.31  1,829,559.71  1,940,792.63  1,955,721.68  2,143,353.81  ...
# 1    769,612.36  1,731,744.62  1,743,978.66  2,057,439.02  2,057,829.69  ...
# 2  5,949,408.99 11,419,210.08  7,934,652.10  8,641,517.13  8,531,576.49  ...
# 3    470,676.43    808,448.39    771,687.83    876,091.18    896,952.53  ...
# 4 13,162,823.43 21,762,104.16 20,126,081.01 22,149,375.82 23,436,682.75  ...
#
#        2020/Jul      2020/Ago      2020/Set      2020/Out      2020/Nov  \
# ...

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis.head()
# Out:
#                        2007/Ago   2007/Set     2007/Out     2007/Nov  \
# Unidade da Federação
# 11 Rondônia            4,209.37  16,397.03   133,645.19   346,912.84
# 12 Acre               10,470.07  14,001.71    86,200.85   301,323.68
# 13 Amazonas           35,752.72  45,570.64   416,012.30 2,020,381.79
# 14 Roraima             4,785.91  11,858.63    43,852.67   369,328.51
# 15 Pará              181,159.29 433,414.74 1,893,197.50 5,105,406.44
#
#                           2007/Dez      2008/Jan      2008/Fev      2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711,758.31  1,829,559.71  1,940,792.63  1,955,721.68
# 12 Acre                 769,612.36  1,731,744.62  1,743,978.66  2,057,439.02
# 13 Amazonas           5,949,408.99 11,419,210.08  7,934,652.10  8,641,517.13
# 14 Roraima              470,676.43    808,448.39    771,687.83    876,091.18
# 15 Pará              13,162,823.43 21,762,104.16 20,126,081.01 22,149,375.82
#
# ...

# %%
usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8,909,111.89
# 12 Acre        2,981,072.98
# 13 Amazonas   16,493,719.52
# 14 Roraima     3,181,321.82
# 15 Pará       36,462,011.47
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago        10,470.07
# 2007/Set        14,001.71
# 2007/Out        86,200.85
# 2007/Nov       301,323.68
# 2007/Dez       769,612.36
#                 ...
# 2020/Dez     3,711,660.71
# 2021/Jan     3,005,561.16
# 2021/Fev     2,272,733.90
# 2021/Mar     1,137,341.65
# Total      450,048,530.47
# Name: 12 Acre, Length: 165, dtype: float64

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                 4,209.37  10,470.07    35,752.72    4,785.91
# 2007/Set                16,397.03  14,001.71    45,570.64   11,858.63
# 2007/Out               133,645.19  86,200.85   416,012.30   43,852.67
# 2007/Nov               346,912.84 301,323.68 2,020,381.79  369,328.51
# 2007/Dez               711,758.31 769,612.36 5,949,408.99  470,676.43
#
# Unidade da Federação       15 Pará   16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago                181,159.29  33,672.74      4,113.76   385,330.18
# 2007/Set                433,414.74 104,822.98     76,633.06 1,018,352.93
# 2007/Out              1,893,197.50 118,378.28    343,702.61 2,277,717.78
# 2007/Nov              5,105,406.44 226,661.18  1,068,685.94 4,334,468.23
# 2007/Dez             13,162,823.43 844,019.90  3,022,200.87 8,832,514.85
#
# Unidade da Federação     22 Piauí      23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
ax = usaveis.T.plot(figsize=(10,6))
plt.show()

# %%
usaveis = usaveis.drop("Total", axis=1)

# %% [markdown]
# ### Desafio 01: Reposicionar a legenda do gráfico em uma posição mais adequada

# %%
ax = usaveis.T.plot(figsize=(10,7.5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(bbox_to_anchor = (1, 1))
plt.show()

# %% [markdown]
# ### Desafio 02: Plotar o gráfico de linha com apenas 5 estados de sua preferência

# %%
estados_selecionados = usaveis.loc[['21 Maranhão','15 Pará','23 Ceará','41 Paraná','51 Mato Grosso']]
estados_selecionados
# Out:
#                        2007/Ago     2007/Set     2007/Out      2007/Nov  \
# Unidade da Federação
# 21 Maranhão          385,330.18 1,018,352.93 2,277,717.78  4,334,468.23
# 15 Pará              181,159.29   433,414.74 1,893,197.50  5,105,406.44
# 23 Ceará             357,904.65   572,356.18 1,865,065.71  5,131,814.39
# 41 Paraná            554,800.22 1,431,708.01 4,630,402.44 11,120,030.79
# 51 Mato Grosso        63,562.50   232,444.62   927,219.59  1,740,439.60
#
#                           2007/Dez      2008/Jan      2008/Fev      2008/Mar  \
# Unidade da Federação
# 21 Maranhão           8,832,514.85 21,551,600.33 13,452,263.93 14,750,895.33
# 15 Pará              13,162,823.43 21,762,104.16 20,126,081.01 22,149,375.82
# 23 Ceará             10,798,042.86 32,444,328.54 27,643,304.86 30,085,370.22
# 41 Paraná            28,790,722.87 58,081,334.45 48,855,046.46 55,611,791.07
# 51 Mato Grosso        5,394,225.43  8,213,438.64  7,929,894.93  9,416,367.68
#
# ...

# %%
ax = estados_selecionados.T.plot(figsize=(10,7.5))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(bbox_to_anchor = (1, 1))
plt.show()

# %% [markdown]
# ### AULA 03

# %%
usaveis.T.columns[0]
# Out:
# '11 Rondônia'

# %%
usaveis.T.columns[1:4]
# Out:
# Index(['12 Acre', '13 Amazonas', '14 Roraima'], dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.index
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis[:5]
# Out:
#                        2007/Ago   2007/Set     2007/Out     2007/Nov  \
# Unidade da Federação
# 11 Rondônia            4,209.37  16,397.03   133,645.19   346,912.84
# 12 Acre               10,470.07  14,001.71    86,200.85   301,323.68
# 13 Amazonas           35,752.72  45,570.64   416,012.30 2,020,381.79
# 14 Roraima             4,785.91  11,858.63    43,852.67   369,328.51
# 15 Pará              181,159.29 433,414.74 1,893,197.50 5,105,406.44
#
#                           2007/Dez      2008/Jan      2008/Fev      2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711,758.31  1,829,559.71  1,940,792.63  1,955,721.68
# 12 Acre                 769,612.36  1,731,744.62  1,743,978.66  2,057,439.02
# 13 Amazonas           5,949,408.99 11,419,210.08  7,934,652.10  8,641,517.13
# 14 Roraima              470,676.43    808,448.39    771,687.83    876,091.18
# 15 Pará              13,162,823.43 21,762,104.16 20,126,081.01 22,149,375.82
#
# ...

# %%
usaveis[:7].T.plot(figsize=(10,6))
plt.show()

# %%
usaveis.sample(n=7)
# Out:
#                          2007/Ago     2007/Set      2007/Out      2007/Nov  \
# Unidade da Federação
# 33 Rio de Janeiro      469,469.34   921,646.57  2,994,664.57  7,250,528.08
# 35 São Paulo         1,665,349.90 4,434,168.64 14,577,395.84 35,032,259.98
# 42 Santa Catarina      693,955.05 1,092,964.12  3,562,300.82  7,578,502.38
# 12 Acre                 10,470.07    14,001.71     86,200.85    301,323.68
# 21 Maranhão            385,330.18 1,018,352.93  2,277,717.78  4,334,468.23
# 11 Rondônia              4,209.37    16,397.03    133,645.19    346,912.84
# 13 Amazonas             35,752.72    45,570.64    416,012.30  2,020,381.79
#
#                           2007/Dez         2008/Jan       2008/Fev  \
# Unidade da Federação
# 33 Rio de Janeiro    13,627,123.27   251,511,992.03  44,128,159.73
# 35 São Paulo         76,668,547.41 1,038,067,423.15 172,961,999.58
# 42 Santa Catarina    14,772,555.10    53,034,384.67  24,409,572.92
# ...

# %%
from numpy.random import seed

seed(1000)

usaveis.sample(n=7)
# Out:
#                          2007/Ago     2007/Set      2007/Out      2007/Nov  \
# Unidade da Federação
# 14 Roraima               4,785.91    11,858.63     43,852.67    369,328.51
# 42 Santa Catarina      693,955.05 1,092,964.12  3,562,300.82  7,578,502.38
# 51 Mato Grosso          63,562.50   232,444.62    927,219.59  1,740,439.60
# 43 Rio Grande do Sul 1,049,252.33 3,182,913.14  8,571,312.11 16,592,432.80
# 16 Amapá                33,672.74   104,822.98    118,378.28    226,661.18
# 31 Minas Gerais        971,394.37 2,861,781.50 10,018,011.35 21,730,281.63
# 17 Tocantins             4,113.76    76,633.06    343,702.61  1,068,685.94
#
#                           2007/Dez       2008/Jan      2008/Fev      2008/Mar  \
# Unidade da Federação
# 14 Roraima              470,676.43     808,448.39    771,687.83    876,091.18
# 42 Santa Catarina    14,772,555.10  53,034,384.67 24,409,572.92 27,483,480.50
# 51 Mato Grosso        5,394,225.43   8,213,438.64  7,929,894.93  9,416,367.68
# ...

# %%
usaveis.sum(axis=1)
# Out:
# Unidade da Federação
# 11 Rondônia                 996,410,650.35
# 12 Acre                     450,047,246.65
# 13 Amazonas               1,917,245,104.64
# 14 Roraima                  328,876,551.40
# 15 Pará                   4,705,290,466.69
# 16 Amapá                    309,837,994.87
# 17 Tocantins              1,019,990,254.88
# 21 Maranhão               3,871,010,362.58
# 22 Piauí                  2,280,874,839.37
# 23 Ceará                  6,591,825,335.83
# 24 Rio Grande do Norte    2,660,065,804.91
# 25 Paraíba                2,614,895,825.09
# 26 Pernambuco             8,580,915,668.43
# 27 Alagoas                2,236,401,471.26
# 28 Sergipe                1,215,843,416.10
# 29 Bahia                  9,791,496,136.10
# 31 Minas Gerais          20,418,205,467.78
# 32 Espírito Santo         3,405,838,975.80
# 33 Rio de Janeiro        10,337,229,379.18
# 35 São Paulo             41,386,533,231.31
# 41 Paraná                14,681,341,476.16
# ...

# %%
usaveis['Total'] = usaveis.sum(axis= 1)
usaveis.head()
# Out:
#                        2007/Ago   2007/Set     2007/Out     2007/Nov  \
# Unidade da Federação
# 11 Rondônia            4,209.37  16,397.03   133,645.19   346,912.84
# 12 Acre               10,470.07  14,001.71    86,200.85   301,323.68
# 13 Amazonas           35,752.72  45,570.64   416,012.30 2,020,381.79
# 14 Roraima             4,785.91  11,858.63    43,852.67   369,328.51
# 15 Pará              181,159.29 433,414.74 1,893,197.50 5,105,406.44
#
#                           2007/Dez      2008/Jan      2008/Fev      2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711,758.31  1,829,559.71  1,940,792.63  1,955,721.68
# 12 Acre                 769,612.36  1,731,744.62  1,743,978.66  2,057,439.02
# 13 Amazonas           5,949,408.99 11,419,210.08  7,934,652.10  8,641,517.13
# 14 Roraima              470,676.43    808,448.39    771,687.83    876,091.18
# 15 Pará              13,162,823.43 21,762,104.16 20,126,081.01 22,149,375.82
#
# ...

# %%
ordenado_por_total = usaveis.sort_values('Total', ascending=False)

# %%
ordenado_por_total = ordenado_por_total.drop('Total', axis=1)

# %%
ordenado_por_total.head()
# Out:
#                          2007/Ago     2007/Set      2007/Out      2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1,665,349.90 4,434,168.64 14,577,395.84 35,032,259.98
# 31 Minas Gerais        971,394.37 2,861,781.50 10,018,011.35 21,730,281.63
# 41 Paraná              554,800.22 1,431,708.01  4,630,402.44 11,120,030.79
# 43 Rio Grande do Sul 1,049,252.33 3,182,913.14  8,571,312.11 16,592,432.80
# 33 Rio de Janeiro      469,469.34   921,646.57  2,994,664.57  7,250,528.08
#
#                           2007/Dez         2008/Jan       2008/Fev  \
# Unidade da Federação
# 35 São Paulo         76,668,547.41 1,038,067,423.15 172,961,999.58
# 31 Minas Gerais      43,429,517.54   206,208,080.90  70,301,089.50
# 41 Paraná            28,790,722.87    58,081,334.45  48,855,046.46
# 43 Rio Grande do Sul 30,134,255.70    51,064,610.03  45,897,704.82
# 33 Rio de Janeiro    13,627,123.27   251,511,992.03  44,128,159.73
#
# ...

# %%
ax = ordenado_por_total.head().T.plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(bbox_to_anchor = (1, 1))
plt.title("Os 5 Maiores Gastos da Saúde por unidade da federação (R$)")
plt.show()

# %%
colunas_interessadas = ordenado_por_total.columns[6:]

ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
ax = ordenado_por_total.head().T.plot(figsize=(10,6))

# %% [markdown]
# ### Desafio 01: Escolher uma palete de cores mais adequada do matplotlib.

# %%
import seaborn as sns
from matplotlib import pyplot

# %%
import random

random.seed(1000)

cores = []

for i in range(27):
    r = lambda: random.randint(0,255)
    
    '#%02X%02X%02X' % (r(),r(),r())
    
    cores.append('#%02X%02X%02X' % (r(),r(),r()))

# %%
customPalette = sns.set_palette(sns.color_palette(cores))

plt.figure(figsize=(12,8))
ax = sns.lineplot(data=usaveis.drop('Total', axis=1).T, dashes=False, palette= customPalette)

ax.legend(bbox_to_anchor = (1, 1))
plt.show()

# %% [markdown]
# ### Desafio 02: Adicionar uma coluna mostrando a região (Norte, Nodeste, Sul, Suldeste e Centro-Oeste) de cada estado.

# %%
def RetornarRegiao(x):
    regiao = ''
    
    x = x[0]
    
    if (x == '1'): regiao = 'Norte'       
    elif (x == '2'): regiao = 'Nordeste'
    elif (x == '3'): regiao = 'Sudeste'
    elif (x == '4'): regiao = 'Sul'
    elif (x == '5'): regiao = 'Centro-Oeste'
    
    return regiao

# %%
usaveis['Região'] = usaveis.index.map(RetornarRegiao)
usaveis.head()
# Out:
#                        2007/Ago   2007/Set     2007/Out     2007/Nov  \
# Unidade da Federação
# 11 Rondônia            4,209.37  16,397.03   133,645.19   346,912.84
# 12 Acre               10,470.07  14,001.71    86,200.85   301,323.68
# 13 Amazonas           35,752.72  45,570.64   416,012.30 2,020,381.79
# 14 Roraima             4,785.91  11,858.63    43,852.67   369,328.51
# 15 Pará              181,159.29 433,414.74 1,893,197.50 5,105,406.44
#
#                           2007/Dez      2008/Jan      2008/Fev      2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711,758.31  1,829,559.71  1,940,792.63  1,955,721.68
# 12 Acre                 769,612.36  1,731,744.62  1,743,978.66  2,057,439.02
# 13 Amazonas           5,949,408.99 11,419,210.08  7,934,652.10  8,641,517.13
# 14 Roraima              470,676.43    808,448.39    771,687.83    876,091.18
# 15 Pará              13,162,823.43 21,762,104.16 20,126,081.01 22,149,375.82
#
# ...

# %% [markdown]
# ### Desafio 03: Formatar o gráfico de custos por mês dos 5 estados, deixando ele agradável (Bonitão, segundo o Gui)

# %%
ax = ordenado_por_total.head().T.plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(bbox_to_anchor = (1, 1))
plt.title("Os 5 Maiores Gastos da Saúde por unidade da federação (R$)")
plt.show()

# %% [markdown]
# ### Desafio 04: Adicione o seu estado aos 5 estados plotados anteriormente

# %%
ordenado_por_total.index[11]
# Out:
# '21 Maranhão'

# %%
add_maranhao = ordenado_por_total.index[:5].tolist()

# %%
add_maranhao.append(ordenado_por_total.index[11])

# %%
add_maranhao
# Out:
# ['35 São Paulo',
#  '31 Minas Gerais',
#  '41 Paraná',
#  '43 Rio Grande do Sul',
#  '33 Rio de Janeiro',
#  '21 Maranhão']

# %%
ax = ordenado_por_total.loc[add_maranhao].T.plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(bbox_to_anchor = (1, 1))
plt.show()

# %% [markdown]
# ### Desafio 05: Buscar os casos de dengue no Brasil (época de maior número de casos e regiões mais atingidas) e se os picos de alguns estados em fevereiro e verão de modo geral, pode ser reflexos dos casos de dengue

# %%
mypath = '.\\Dengue\\'

# %%
from os import listdir
from os.path import isfile, join
arquivos_dengue = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
arquivos_dengue
# Out:
# ['2008_A122708189_28_143_208.csv',
#  '2009_A123210189_28_143_208.csv',
#  '2010_A122738189_28_143_208.csv',
#  '2011_A122751189_28_143_208.csv',
#  '2012_A122804189_28_143_208.csv',
#  '2013_A122816189_28_143_208.csv',
#  '2014_A122842189_28_143_208.csv',
#  '2015_A122900189_28_143_208.csv',
#  '2016_A122915189_28_143_208.csv',
#  '2017_A123110189_28_143_208.csv',
#  '2018_A122939189_28_143_208.csv',
#  '2019_A122953189_28_143_208.csv',
#  '2020_A123006189_28_143_208.csv']

# %%
list_base_dengue = []
index = 0

for f in arquivos_dengue:
    
    
    if (index <= 5): 
    
        df = pd.read_csv(mypath + f, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter=17, thousands='.', decimal=',')
        
    elif (index == 8):
        
        df = pd.read_csv(mypath + f, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter=20, thousands='.', decimal=',')

    else:
        
        df = pd.read_csv(mypath + f, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter=19, thousands='.', decimal=',')
 
    
    estados = df['UF de notificação']
    
    df.drop('Total', axis = 1, inplace=True )
    
    df.drop('UF de notificação', axis = 1, inplace=True )
    
    df.columns = f[:4] + '/' + df.columns

    index += 1
    
    
    list_base_dengue.append(df)
# Out:
# <ipython-input-52-1558a95ea81c>:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(mypath + f, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter=17, thousands='.', decimal=',')
# <ipython-input-52-1558a95ea81c>:17: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(mypath + f, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter=19, thousands='.', decimal=',')
# <ipython-input-52-1558a95ea81c>:13: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(mypath + f, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter=20, thousands='.', decimal=',')

# %%
df.columns
# Out:
# Index(['2020/Jan', '2020/Fev', '2020/Mar', '2020/Abr', '2020/Mai', '2020/Jun',
#        '2020/Jul', '2020/Ago', '2020/Set', '2020/Out', '2020/Nov', '2020/Dez'],
#       dtype='object')

# %%
dados_dengue = pd.concat (list_base_dengue, axis=1)
dados_dengue['Unidade da Federação'] = estados
dados_dengue.head()
# Out:
#    2008/Jan  2008/Fev  2008/Mar  2008/Abr  2008/Mai  2008/Jun 2008/Jul  \
# 0      1510      1052      1050      1188       323        94       46
# 1        82       140       162       234       176        95       72
# 2      1134      1716      1536      1417       665       159      130
# 3        82       187       224       466       650       467      972
# 4      4314      3369      2472      2643       832       486      257
#
#    2008/Ago 2008/Set  2008/Out  ...  2020/Abr  2020/Mai  2020/Jun  2020/Jul  \
# 0        14       16        25  ...       671       530       286       216
# 1        36       90       115  ...       221       582       372       181
# 2        85       47       105  ...       416       343       372       232
# 3       516      450       273  ...        13         4         3        15
# 4       127      165       275  ...       424       353       175        94
#
#    2020/Ago  2020/Set 2020/Out  2020/Nov 2020/Dez  Unidade da Federação
# ...

# %%
dengue_usaveis = dados_dengue.mean().index.tolist()
dengue_usaveis.insert(0,"Unidade da Federação")
dengue_usaveis
# Out:
# ['Unidade da Federação',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Ago',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Jun',
#  '2009/Ago',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
# ...

# %%
dengue_usaveis = dados_dengue[dengue_usaveis]
dengue_usaveis.head()
# Out:
#   Unidade da Federação  2008/Jan  2008/Fev  2008/Mar  2008/Abr  2008/Mai  \
# 0          11 Rondônia      1510      1052      1050      1188       323
# 1              12 Acre        82       140       162       234       176
# 2          13 Amazonas      1134      1716      1536      1417       665
# 3           14 Roraima        82       187       224       466       650
# 4              15 Pará      4314      3369      2472      2643       832
#
#    2008/Jun  2008/Ago  2008/Out  2008/Nov  ...  2019/Jul  2019/Ago  2019/Set  \
# 0        94        14        25        82  ...       130        80        25
# 1        95        36       115       271  ...       137       174       145
# 2       159        85       105       222  ...        57        47       101
# 3       467       516       273       275  ...        54        76       156
# 4       486       127       275       348  ...       207       225       270
#
# ...

# %%
dengue_usaveis.set_index('Unidade da Federação', inplace=True)

# %%
ax = dengue_usaveis.T.plot(figsize=(12,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(bbox_to_anchor = (1, 1))
plt.show()

# %%
dengue_usaveis['Total'] = dengue_usaveis.sum(axis=1)
# Out:
# <ipython-input-59-bfe9de206189>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dengue_usaveis['Total'] = dengue_usaveis.sum(axis=1)

# %%
dengue_ordenado_total = dengue_usaveis.sort_values('Total',ascending=False)

dengue_ordenado_total = dengue_ordenado_total.drop('Total', axis=1)

dengue_ordenado_total.head()
# Out:
#                       2008/Jan  2008/Fev  2008/Mar  2008/Abr  2008/Mai  \
# Unidade da Federação
# 35 São Paulo               964      1243      2112      3910      1640
# 31 Minas Gerais           1449      2896      8086     19092     11321
# 52 Goiás                  2640      3692      6012     11862      5654
# 33 Rio de Janeiro        13373     19025     53182     71547     27866
# 29 Bahia                  1194      2522      5007     10642      6539
#
#                       2008/Jun  2008/Ago  2008/Out  2008/Nov  2008/Dez  ...  \
# Unidade da Federação                                                    ...
# 35 São Paulo               573       190       132       190       297  ...
# 31 Minas Gerais           3690       201       293       563       910  ...
# 52 Goiás                  1925       347       535       764      1233  ...
# 33 Rio de Janeiro         6634      1499      1389       979      1454  ...
# ...

# %%
dengue_ordenado_total[0:5].T.plot(figsize=(12,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(bbox_to_anchor = (1, 1))
plt.title('Os 5 estados com maiores casos de dengue')
plt.show()

# %%
ax = dengue_ordenado_total.loc['35 São Paulo'].T.plot(figsize=(12,7))

ax = ordenado_por_total.loc['35 São Paulo'].T.plot(secondary_y=True, figsize=(12,7))

plt.title('Comparação: Gasto com o SUS X Casos de Dengue em São Paulo')

plt.show()

# %%
ax = dengue_ordenado_total.loc['31 Minas Gerais'].T.plot(figsize=(12,7))

ax = ordenado_por_total.loc['31 Minas Gerais'].T.plot(secondary_y=True, figsize=(12,7))

plt.title('Comparação: Gasto com o SUS X Casos de Dengue em Minas Gerais')

plt.show()

# %%
ax = dengue_ordenado_total.loc['52 Goiás'].T.plot(figsize=(12,7))

ax = ordenado_por_total.loc['52 Goiás'].T.plot(secondary_y=True, figsize=(12,7))

plt.title('Comparação: Gasto com o SUS X Casos de Dengue em Goiás')

plt.show()

# %% [markdown]
# ### Conclusão: Ao comparar em gráficos os casos de dengue em alguns estados com relação aos gastos da saúde, verificamos que não existe correlão dos picos no gastos com aumento de casos de dengue nesses estados.

# %% [markdown]
# ### Desafio 06: Plotar o gráfico dos custos apenas dos estados da região sudeste e verificar se os picos de 2013/Fev teve comportamento similar em todos os demais estados da região

# %%
ordenado_por_total_regiao = ordenado_por_total.copy()

# %%
ordenado_por_total_regiao['Região'] = ordenado_por_total_regiao.index.map(RetornarRegiao)
regiao_sudeste = ordenado_por_total_regiao[ordenado_por_total_regiao['Região'] == 'Sudeste'].drop('Região', axis=1)

regiao_sudeste
# Out:
#                            2008/Fev       2008/Mar       2008/Abr  \
# Unidade da Federação
# 35 São Paulo         172,961,999.58 170,556,696.16 170,338,163.23
# 31 Minas Gerais       70,301,089.50  79,119,005.51  79,046,322.41
# 33 Rio de Janeiro     44,128,159.73  42,900,847.02  45,306,499.53
# 32 Espírito Santo     10,032,886.43  12,262,049.08  12,453,466.98
#
#                            2008/Mai       2008/Jun       2008/Jul  \
# Unidade da Federação
# 35 São Paulo         172,462,057.87 175,492,995.85 179,569,910.06
# 31 Minas Gerais       79,268,070.12  79,619,189.20  82,209,206.98
# 33 Rio de Janeiro     43,951,349.46  44,111,107.27  44,359,056.71
# 32 Espírito Santo     11,789,786.09  11,889,687.35  12,205,584.14
#
#                            2008/Ago       2008/Set       2008/Out  \
# Unidade da Federação
# 35 São Paulo         180,005,050.15 180,151,656.17 191,859,884.40
# 31 Minas Gerais       80,374,117.08  82,409,129.30  88,613,476.60
# ...

# %%
ax = regiao_sudeste.T.plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(bbox_to_anchor = (1, 1))
plt.show()

# %% [markdown]
# ### Conclusão: Ao analisar os gráfico comparando os estados da região sudeste, verificamos que houve comportamento similar somente entre dois estados, com picos nos entre o período de Jan/2013 e Fev/2013:  São Paulo e Rio de Janeiro

# %% [markdown]
# ### Desafio 07: Adicionar seu estado escolhido novamente, deixe o gráfico informativo e tire conclusões sobre seus estados comparando com os demais. Tire suas conclusões e compartilhe com a gente.

# %%
ax = ordenado_por_total.loc[add_maranhao].T.plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(bbox_to_anchor = (1, 1))
plt.show()

# %% [markdown]
# ### Conclusão: Ao analisar o gráfico, verificamos que os gastos com saúde no estado do Maranhão é bem inferior comparado aos 5 estados com maiores gastos do Brasil. Provalvemente existe um calculo de distribuição de investimento na saúde por proporção populacional (É preciso uma maior analise validar esta tese).

# %% [markdown]
# ### AULA 04

# %%
ordenado_por_total = ordenado_por_total / 1000000
ordenado_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total[ordenado_por_total.columns[47:143]].head(3).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
meses_filtrados = ordenado_por_total.columns[47:150] 
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(100, 350)
# Out:
# (100.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-12:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-24:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-36:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-60:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total.head(5).T.plot(figsize=(6,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total.head(5).T.plot(figsize=(20,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Desafio 01: Refaça as manipulações feitas em aulas e gaste um tempo analisando os dados e entendendo os efeitos das manipulações

# %% [markdown]
# #### Conclusão: Ao analisar os gráficos com relação a manipulação, a chave é verificar se houve uma alteração no eixo, fazendo recortes das informações. Deve se observar se o eixo começa no 0 (como explicado na aula). Ao alterar as posições dos eixos, é possível distorcer os gráficos passando informações erradas na primeira olhada. Este recurso pode ser utilizado para influenciar ao tomadas de decisões de forma equivocada. Por isso a importância de se ter esse cuidado ao observar os gráficos para as analises.

# %% [markdown]
# ### AULA 05

# %%
ordenado_por_total.columns[-1]
# Out:
# '2021/Mar'

# %%
mes_mais_recente = ordenado_por_total.columns[-1]

# %%
gastos_do_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
gastos_do_mais_recente.plot()
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
gastos_do_mais_recente.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='2021/Mar'>

# %%
gastos_do_mais_recente.sample(frac=1)
# Out:
# Unidade da Federação
# 52 Goiás                  24.87
# 11 Rondônia                4.73
# 23 Ceará                  17.17
# 12 Acre                    1.14
# 24 Rio Grande do Norte     8.73
# 26 Pernambuco             39.47
# 43 Rio Grande do Sul      37.80
# 14 Roraima                 2.38
# 41 Paraná                 43.48
# 53 Distrito Federal       14.73
# 31 Minas Gerais           79.78
# 51 Mato Grosso             8.84
# 17 Tocantins               0.93
# 50 Mato Grosso do Sul      4.04
# 22 Piauí                   9.54
# 27 Alagoas                 8.18
# 42 Santa Catarina         19.38
# 33 Rio de Janeiro         49.15
# 35 São Paulo             177.41
# 16 Amapá                   0.99
# 13 Amazonas                6.80
# 21 Maranhão               17.29
# 32 Espírito Santo         15.61
# 29 Bahia                  31.31
# 25 Paraíba                12.52
# 15 Pará                   13.07
# 28 Sergipe                 3.08
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente / gastos_do_mais_recente["33 Rio de Janeiro"]
# Out:
# Unidade da Federação
# 35 São Paulo             3.61
# 31 Minas Gerais          1.62
# 41 Paraná                0.88
# 43 Rio Grande do Sul     0.77
# 33 Rio de Janeiro        1.00
# 29 Bahia                 0.64
# 26 Pernambuco            0.80
# 42 Santa Catarina        0.39
# 23 Ceará                 0.35
# 52 Goiás                 0.51
# 15 Pará                  0.27
# 21 Maranhão              0.35
# 32 Espírito Santo        0.32
# 24 Rio Grande do Norte   0.18
# 25 Paraíba               0.25
# 53 Distrito Federal      0.30
# 50 Mato Grosso do Sul    0.08
# 22 Piauí                 0.19
# 27 Alagoas               0.17
# 51 Mato Grosso           0.18
# 13 Amazonas              0.14
# 28 Sergipe               0.06
# 17 Tocantins             0.02
# 11 Rondônia              0.10
# 12 Acre                  0.02
# 14 Roraima               0.05
# 16 Amapá                 0.02
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc["33 Rio de Janeiro"]
# Out:
# Unidade da Federação
# 35 São Paulo             3.61
# 31 Minas Gerais          1.62
# 41 Paraná                0.88
# 43 Rio Grande do Sul     0.77
# 33 Rio de Janeiro        1.00
# 29 Bahia                 0.64
# 26 Pernambuco            0.80
# 42 Santa Catarina        0.39
# 23 Ceará                 0.35
# 52 Goiás                 0.51
# 15 Pará                  0.27
# 21 Maranhão              0.35
# 32 Espírito Santo        0.32
# 24 Rio Grande do Norte   0.18
# 25 Paraíba               0.25
# 53 Distrito Federal      0.30
# 50 Mato Grosso do Sul    0.08
# 22 Piauí                 0.19
# 27 Alagoas               0.17
# 51 Mato Grosso           0.18
# 13 Amazonas              0.14
# 28 Sergipe               0.06
# 17 Tocantins             0.02
# 11 Rondônia              0.10
# 12 Acre                  0.02
# 14 Roraima               0.05
# 16 Amapá                 0.02
# Name: 2021/Mar, dtype: float64

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc["33 Rio de Janeiro"]).head(5)
# Out:
# Unidade da Federação
# 35 São Paulo           3.61
# 31 Minas Gerais        1.62
# 41 Paraná              0.88
# 43 Rio Grande do Sul   0.77
# 33 Rio de Janeiro      1.00
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %% [markdown]
# ### Desafio 01: Buscar na documentação do Matplotlib como colocar um grid nos gráficos e adicionar nos gráficos de barra.

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind='bar')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Desafio 02: Fazer um gráfico e uma tabela do gasto dos outros estados em função do seu estado, ou qualquer outro de interesse.

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc["21 Maranhão"]
# Out:
# Unidade da Federação
# 35 São Paulo             10.26
# 31 Minas Gerais           4.61
# 33 Rio de Janeiro         2.84
# 41 Paraná                 2.51
# 26 Pernambuco             2.28
# 43 Rio Grande do Sul      2.19
# 29 Bahia                  1.81
# 52 Goiás                  1.44
# 42 Santa Catarina         1.12
# 21 Maranhão               1.00
# 23 Ceará                  0.99
# 32 Espírito Santo         0.90
# 53 Distrito Federal       0.85
# 15 Pará                   0.76
# 25 Paraíba                0.72
# 22 Piauí                  0.55
# 51 Mato Grosso            0.51
# 24 Rio Grande do Norte    0.50
# 27 Alagoas                0.47
# 13 Amazonas               0.39
# 11 Rondônia               0.27
# 50 Mato Grosso do Sul     0.23
# 28 Sergipe                0.18
# 14 Roraima                0.14
# 12 Acre                   0.07
# 16 Amapá                  0.06
# 17 Tocantins              0.05
# Name: 2021/Mar, dtype: float64

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc["21 Maranhão"]).plot(kind='bar')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Desafio 03: Fazer o cálculo proporcional a população do seu estado e mais um a sua escolha.

# %% [markdown]
# #### Origem dos dados da população por estado:
#
# https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o

# %%
populacao = pd.read_csv('Populacao_Estados.csv', encoding='ISO-8859-1', sep=';')

# %%
populacao.head()
# Out:
#   Unidade da Federação  População
# 0         35 São Paulo   46289333
# 1      31 Minas Gerais   21292666
# 2    33 Rio de Janeiro   17366189
# 3             29 Bahia   14930634
# 4            41 Paraná   11516840

# %%
populacao.set_index('Unidade da Federação', inplace=True)

# %%
populacao = populacao / 1000000

# %%
populacao.head()
# Out:
#                       População
# Unidade da Federação
# 35 São Paulo              46.29
# 31 Minas Gerais           21.29
# 33 Rio de Janeiro         17.37
# 29 Bahia                  14.93
# 41 Paraná                 11.52

# %%
populacao.plot(kind='bar')
plt.grid(True)
plt.show()

# %%
gastos_do_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             177.41
# 31 Minas Gerais           79.78
# 33 Rio de Janeiro         49.15
# 41 Paraná                 43.48
# 26 Pernambuco             39.47
# 43 Rio Grande do Sul      37.80
# 29 Bahia                  31.31
# 52 Goiás                  24.87
# 42 Santa Catarina         19.38
# 21 Maranhão               17.29
# 23 Ceará                  17.17
# 32 Espírito Santo         15.61
# 53 Distrito Federal       14.73
# 15 Pará                   13.07
# 25 Paraíba                12.52
# 22 Piauí                   9.54
# 51 Mato Grosso             8.84
# 24 Rio Grande do Norte     8.73
# 27 Alagoas                 8.18
# 13 Amazonas                6.80
# 11 Rondônia                4.73
# 50 Mato Grosso do Sul      4.04
# 28 Sergipe                 3.08
# 14 Roraima                 2.38
# 12 Acre                    1.14
# 16 Amapá                   0.99
# 17 Tocantins               0.93
# Name: 2021/Mar, dtype: float64

# %%
populacao['Gasto SUS'] = gastos_do_mais_recente

populacao.head()
# Out:
#                       População  Gasto SUS
# Unidade da Federação
# 35 São Paulo              46.29     177.41
# 31 Minas Gerais           21.29      79.78
# 33 Rio de Janeiro         17.37      49.15
# 29 Bahia                  14.93      31.31
# 41 Paraná                 11.52      43.48

# %%
populacao['Gasto SUS/Populacao'] = populacao['Gasto SUS']/ populacao['População']
populacao.head()
# Out:
#                       População  Gasto SUS  Gasto SUS/Populacao
# Unidade da Federação
# 35 São Paulo              46.29     177.41                 3.83
# 31 Minas Gerais           21.29      79.78                 3.75
# 33 Rio de Janeiro         17.37      49.15                 2.83
# 29 Bahia                  14.93      31.31                 2.10
# 41 Paraná                 11.52      43.48                 3.78

# %%
populacao['Gasto SUS/Populacao'].sort_values(ascending=False).plot(kind='bar', figsize=(11,6))
plt.grid(True)
plt.show()

# %% [markdown]
# ### Desafio 04: Faça uma análise dos dados analisados, levante hipóteses e compartilhe com a gente no Discord.

# %% [markdown]
# ### Desafio 05: Reproduza as análises feitas em aulas, refletindo e levantando hipóteses.
